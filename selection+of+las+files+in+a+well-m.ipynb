# %%
import numpy as np
well_las_attr_dict=np.load('well_las_attr_dict.npy')[0]
# well_las_dict=np.load('well_las_dict.npy')[0]
# well_las_attr_dict

# %%
well_las_attr_dict
# Out:
# {'W1': {'W1_12in_SonicVISION-APWD_RM_ASCII_DCS-Processed.las': {'categories': [],
#    'depthrange': (3183.2918, 1520.303),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_12in_SonicVISION-APWD_RM_ASCII_DCS-Processed.las'},
#   'W1_12in_SonicVISION_RM_ASCII_DCS-Processed_TVDindex.LAS': {'categories': [],
#    'depthrange': (2740.5635, 1507.9523),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_12in_SonicVISION_RM_ASCII_DCS-Processed_TVDindex.LAS'},
#   'W1_12in_VISION_APWD_MD_RM_LAS.las': {'categories': ['RHOB', 'NPHI', 'LLD'],
#    'depthrange': (1584.96, 3211.2204),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_12in_VISION_APWD_MD_RM_LAS.las'},
#   'W1_12in_VISION_APWD_TVD_RM_LAS.las': {'categories': ['RHOB', 'NPHI', 'LLD'],
#    'depthrange': (1583.5884, 2756.4588),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_12in_VISION_APWD_TVD_RM_LAS.las'},
#   'W1_17in_ASCII_RM_PWD.las': {'categories': [],
#    'depthrange': ('24-SEP-2006 21', '27-SEP-2006 21'),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_17in_ASCII_RM_PWD.las'},
#   'W1_17in_VISIONRes-APWD_RM_ASCII_600m-1591m.las': {'categories': ['LLD'],
#    'depthrange': (599.9988, 1591.6656),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_17in_VISIONRes-APWD_RM_ASCII_600m-1591m.las'},
#   'W1_6in_ASCII_RM_PWD.LAS': {'categories': [],
#    'depthrange': ('19-OCT-2006 20', '24-OCT-2006 08'),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_6in_ASCII_RM_PWD.LAS'},
#   'W1_6in_VISIONResistivity-APWD_RM_MD_ASCII.las': {'categories': ['LLD'],
#    'depthrange': (3489.96, 3660.8004),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_6in_VISIONResistivity-APWD_RM_MD_ASCII.las'},
#   'W1_6in_VISIONResistivity-APWD_RM_TVD_ASCII.las': {'categories': ['LLD'],
#    'depthrange': (2919.3744, 3019.5012),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_6in_VISIONResistivity-APWD_RM_TVD_ASCII.las'},
#   'W1_8in_SonicVISION-APWD_RM_ASCII_DCS-Processed.las': {'categories': [],
#    'depthrange': (3468.7754, 3190.0358),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_8in_SonicVISION-APWD_RM_ASCII_DCS-Processed.las'},
#   'W1_8in_SonicVISION_RM_ASCII_DCS-Processed_TVDindex.LAS': {'categories': [],
#    'depthrange': (2980.6392, 2744.724),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_8in_SonicVISION_RM_ASCII_DCS-Processed_TVDindex.LAS'},
#   'W1_8in_VISION-APWD_RM_MD_ASCII.las': {'categories': ['NPHI', 'LLD'],
#    'depthrange': (3189.732, 3496.2084),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_8in_VISION-APWD_RM_MD_ASCII.las'},
#   'W1_8in_VISION-APWD_RM_TVD_ASCII.las': {'categories': ['NPHI', 'LLD'],
#    'depthrange': (nan, nan),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_8in_VISION-APWD_RM_TVD_ASCII.las'},
#   'W1_SUITE1_COMPOSITE.las': {'categories': ['CAL',
#     'DTC',
#     'DTS',
#     'GR',
#     'SGR',
#     'RHOB',
#     'NPHI',
#     'PE',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (551.6118, 1573.9872),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE1_COMPOSITE.las'},
#   'W1_SUITE1_ZDL_CN_HIRES.las': {'categories': ['CAL', 'GR', 'RHOB', 'PE'],
#    'depthrange': (551.5737, 1573.9872),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE1_ZDL_CN_HIRES.las'},
#   'W1_SUITE2_COMPOSITE.las': {'categories': ['CAL',
#     'DTC',
#     'DTS',
#     'GR',
#     'SGR',
#     'RHOB',
#     'NPHI',
#     'PE',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (1477.7466, 3219.2976),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE2_COMPOSITE.las'},
#   'W1_SUITE2_COMPOSITE_TVD.las': {'categories': ['CAL',
#     'DTC',
#     'DTS',
#     'GR',
#     'SGR',
#     'RHOB',
#     'NPHI',
#     'PE',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (1476.8322, 2773.5276),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE2_COMPOSITE_TVD.las'},
#   'W1_SUITE2_ZDL_CN_HIRES.las': {'categories': ['CAL', 'GR', 'RHOB', 'PE'],
#    'depthrange': (1477.7466, 3219.2976),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE2_ZDL_CN_HIRES.las'},
#   'W1_SUITE2_ZDL_CN_HIRES_TVD.las': {'categories': ['CAL', 'GR', 'RHOB', 'PE'],
#    'depthrange': (1476.8322, 2773.5276),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE2_ZDL_CN_HIRES_TVD.las'},
#   'W1_SUITE4_COMPOSITE.las': {'categories': ['CAL',
#     'GR',
#     'SGR',
#     'RHOB',
#     'NPHI',
#     'PE',
#     'LLD',
#     'SP'],
#    'depthrange': (3469.9956, 3672.5352),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE4_COMPOSITE.las'},
#   'W1_SUITE4_COMPOSITE_TVD.las': {'categories': ['CAL',
#     'GR',
#     'SGR',
#     'RHOB',
#     'NPHI',
#     'PE',
#     'LLD',
#     'SP'],
#    'depthrange': (2686.9644, 3027.5784),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE4_COMPOSITE_TVD.las'},
#   'W1_SUITE4_ZDL_CN_HIRES.las': {'categories': ['CAL', 'GR', 'RHOB', 'PE'],
#    'depthrange': (3460.0134, 3672.002),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE4_ZDL_CN_HIRES.las'},
#   'W1_SUITE4_ZDL_CN_HIRES_TVD.las': {'categories': ['CAL', 'GR', 'RHOB', 'PE'],
#    'depthrange': (2686.7739, 3027.5784),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W1\\LAS\\W1_SUITE4_ZDL_CN_HIRES_TVD.las'}},
#  'W2': {'W2_12in_DLIS_1430-3100m.las': {'categories': ['RHOB', 'NPHI', 'LLD'],
#    'depthrange': (1429.9692, 3099.9684),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W2\\LAS\\W2_12in_DLIS_1430-3100m.las'},
#   'W2_17in_APWD-Time_LAS.las': {'categories': [],
#    'depthrange': ('09-DEC-2006 16', '12-DEC-2006 10'),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W2\\LAS\\W2_17in_APWD-Time_LAS.las'},
#   'W2_8in_Pilot_VISION_Resistivity_APWD_TIME_LAS.LAS': {'categories': [],
#    'depthrange': ('02-DEC-2006 06', '02-DEC-2006 16'),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W2\\LAS\\W2_8in_Pilot_VISION_Resistivity_APWD_TIME_LAS.LAS'},
#   'W2_8in_Pilot_VISION_Resistivity_MD_LAS.LAS': {'categories': ['LLD'],
#    'depthrange': (119.7864, 503.9868),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W2\\LAS\\W2_8in_Pilot_VISION_Resistivity_MD_LAS.LAS'},
#   'W2_VISION_RESISTIVITY-APWD_17in_RM_500-1445m.las': {'categories': ['LLD'],
#    'depthrange': (499.872, 1445.2092),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W2\\LAS\\W2_VISION_RESISTIVITY-APWD_17in_RM_500-1445m.las'}},
#  'W3': {'Dibrugarh-1_WSTT_DRA.las': {'categories': ['CAL', 'DTC', 'GR'],
#    'depthrange': (4267.5996, 4433.7998),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh-1_WSTT_DRA.las'},
#   'Dibrugarh-1_WSTT_Interm2.las': {'categories': ['GR'],
#    'depthrange': (1819.5, 3308.2),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh-1_WSTT_Interm2.las'},
#   'Dibrugarh1_DLLSplice_150-4428.las': {'categories': ['GR',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (4428.89941, 150.09935),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DLLSplice_150-4428.las'},
#   'Dibrugarh1_DLL_150-1852.las': {'categories': ['CAL',
#     'GR',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (1852.19995, 150.09993),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DLL_150-1852.las'},
#   'Dibrugarh1_DLL_1772-3310.las': {'categories': ['CAL',
#     'GR',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (3310.5, 1772.49998),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DLL_1772-3310.las'},
#   'Dibrugarh1_DLL_3293-4300.las': {'categories': ['CAL',
#     'GR',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (4300.8999, 3293.09989),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DLL_3293-4300.las'},
#   'Dibrugarh1_DLL_3961-4367.las': {'categories': ['CAL',
#     'GR',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (4367.022, 3961.638),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DLL_3961-4367.las'},
#   'Dibrugarh1_DLL_4267-4428.las': {'categories': ['CAL',
#     'GR',
#     'LLD',
#     'LLS',
#     'MSFL',
#     'SP'],
#    'depthrange': (4428.8999, 4267.7999),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DLL_4267-4428.las'},
#   'Dibrugarh1_DSI_INCL_3246-4367.las': {'categories': ['DTC'],
#    'depthrange': (4367.6316, 3246.882),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DSI_INCL_3246-4367.las'},
#   'Dibrugarh1_DT1_124-1852.las': {'categories': ['DTC', 'GR'],
#    'depthrange': (124.0, 1852.80003),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_DT1_124-1852.las'},
#   'Dibrugarh1_SDL_150-1853.las': {'categories': ['CAL',
#     'GR',
#     'RHOB',
#     'NPHI',
#     'PE'],
#    'depthrange': (1853.0, 150.29997),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_SDL_150-1853.las'},
#   'Dibrugarh1_SDL_1832-3308.las': {'categories': ['CAL',
#     'GR',
#     'RHOB',
#     'NPHI',
#     'PE'],
#    'depthrange': (3308.8999, 1832.89988),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_SDL_1832-3308.las'},
#   'Dibrugarh1_SDL_3254-4358.las': {'categories': ['CAL',
#     'GR',
#     'RHOB',
#     'NPHI',
#     'PE'],
#    'depthrange': (4358.7924, 3254.502),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_SDL_3254-4358.las'},
#   'Dibrugarh1_SDL_3254-4428.las': {'categories': ['CAL', 'GR', 'RHOB', 'NPHI'],
#    'depthrange': (4428.2998, 3254.49979),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_SDL_3254-4428.las'},
#   'Dibrugarh1_SDL_4285-4428.las': {'categories': ['CAL',
#     'GR',
#     'RHOB',
#     'NPHI',
#     'PE'],
#    'depthrange': (4428.2998, 4285.7998),
#    'path': 'D:\\Ameyem Office\\Projects\\Cairn\\\\W3\\LAS\\Dibrugarh1_SDL_4285-4428.las'}}}

# %%
# awell=well_las_attr_dict['BRHL-56']
# lwithgr={}
# lwithoutgr={}

# for l in awell:
# #     print(awell[l]['depthrange'],', '.join(awell[l]['categories']))
#     if 'GR' in awell[l]['categories']:
#         lwithgr[l]=awell[l]
#     else:
#         lwithoutgr[l]=awell[l]
# print_logs(lwithgr)  
# print('*************************************')
# print_logs(lwithoutgr)  


# sorted_well,minmax,darray=sort_ranges(awell)
# print_logs(sorted_well)
# print(logs)
# sort_indx
# print(logs[sort_indx])
def print_logs(awell):
    for l in awell:
        print('({:4.1f}-{:4.1f}) - {:20}'.format(min(awell[l]['depthrange']),max(awell[l]['depthrange']),
                                                 ', '.join(awell[l]['categories'])))
def printSuits(suits):
    for i in suits:
        print('   ',i)
        for l in suits[i]:
#             print('     ',l,suits[i][l]['depthrange'],', '.join(suits[i][l]['categories']))
            print('     ',l,': ({:4.1f}-{:4.1f}) - {:20}'.format(min(suits[i][l]['depthrange']),
                                     max(suits[i][l]['depthrange']),', '.join(suits[i][l]['categories'])))

def sort_ranges(awell):
#     minranges=np.array([min(awell[l]['depthrange']) for l in awell])
#     maxranges=np.array([max(awell[l]['depthrange']) for l in awell])
    
    darray=np.array([(min(awell[l]['depthrange']),max(awell[l]['depthrange'])) for l in awell])
    minmaxs=min(darray[:,0]),max(darray[:,1])
    logs=np.array(list(awell.keys()))
    sort_indx=np.argsort(darray[:,0])
    # sort_indx=sort_indx[::-1]
    sorted_well={}
    for l in logs[sort_indx]:
        sorted_well[l]=awell[l]
    return sorted_well,minmaxs,darray[sort_indx]
# def removeRepetedRuns(awell):
import matplotlib.pyplot as plt
def get_rangearray(awell):
    return np.array([(min(awell[l]['depthrange']),max(awell[l]['depthrange'])) for l in awell])

# plt.hist(minranges,20)
# maxranges-minranges,minmax
# rangelength=100

def getLfileWIndex(awell,indexes):
    resultwell={}
    for fkey in np.array(list(awell.keys()))[indexes]:
        resultwell[fkey]=awell[fkey]
    return resultwell
def getLoglist(awell):
    logs=[]
    for l in awell:
        logs.extend(awell[l]['categories'])
    return np.unique(logs)

# getIndxGroups(dranges[:,0])

# %%
# j=[1,2,34,4]
# j.pop(2)
# j
# # bwell=awell.copy()
# # del bwell['jagun-1_wire.las']
class Logset():
    def __init__(self,singlewell):
        self.well=singlewell
        self.key=list(singlewell.keys())[0]

        self.logs=self.well[self.key]['categories']
        self.mindepth=min(self.well[self.key]['depthrange'])
        self.maxdepth=max(self.well[self.key]['depthrange'])
    def isRangesubset(self,minmaxes):
#         print(self.mindepth,self.maxdepth)
#         print(minmaxes)
        if (minmaxes[0]>self.mindepth )& (minmaxes[1]<self.maxdepth):
            return True
        else:
            return False
    def isSubset(self,otherwell):
        owell=Logset(otherwell)
        if self.isRangesubset([owell.mindepth,owell.maxdepth]):
            for ol in owell.logs:
                if ol not in self.logs:
                    return False
        else:
            return False
        return True
# def removeSubsets(awell):       
# #     sorted_well,minmaxs=sort_ranges(awell)
#     reswell=awell.copy()
#     keys=list(awell.keys())
#     varkeys=keys.copy()
    
#     for i in range(len(keys)):
#         print(keys[i])
#         if keys[i] in awell.keys():
#             alset=Logset({keys[i]:awell[keys[i]]})
#     #         varkeys.pop(i)
#             for vk in varkeys:            
#                 if alset.isSubset({vk:awell[vk]}):
#                     print('      ',vk,end=', ')
#                     del reswell[vk] 
#                     print(len(reswell.keys()))
#             varkeys=list(reswell.keys())
#             awell=reswell.copy()  
#     return reswell

# awell,removeCorruptlas(awell)

# %%
def getExclusivekeys(key,varkeys,awell):
    if key in awell.keys():
        alset=Logset({key:awell[key]})
        for vk in varkeys:            
            if alset.isSubset({vk:awell[vk]}):
                del awell[vk] 
        varkeys=list(awell.keys())
    return varkeys,awell
def removeSubsets(awell):       
    keys=list(awell.keys())
    varkeys=keys.copy()    
    for key in keys:
        varkeys,awell=getExclusivekeys(key,varkeys,awell)
#     print(varkeys)
    finalkeys=varkeys.copy()
#     print('final keys: ',len(finalkeys))
    for key in varkeys[::-1]:
        finalkeys,awell=getExclusivekeys(key,finalkeys,awell)
#     print('final keys: ',len(finalkeys))
    return awell

def global_logavailability(global_loglist,alas):
    if len(global_loglist)==0:
        return 0,[]
    lcount=0
    not_inGlobal=[]
    for log in global_loglist:
        if log in alas['categories']:
            lcount +=1
        else:
            not_inGlobal.append(log)
    return lcount/len(global_loglist),not_inGlobal

def similarityIndex(alas,blas):
    lcount=0
    for log in alas['categories']:
        if log in blas['categories']:
            lcount +=1
    return lcount/len(alas['categories'])
def getValidloginRun(partwell,list_availability,list_missed_logs):
    local_indx=np.argsort(np.array(list_availability))
    local_indx=local_indx[::-1]
    sorted_la=list_availability[local_indx]
    usorted_la=np.unique(sorted_la)
#     print('usorted la: ',usorted_la)
    lookindex=[]
    for i in range(0,len(sorted_la)):
        if sorted_la[i]==usorted_la[-1]:
            lookindex.append(i)
#     print('indexes found: ',lookindex)
    lookwell=getLfileWIndex(partwell,local_indx[lookindex])
    look_missed_logs=list_missed_logs[local_indx[lookindex]]
    validLFindx=np.argmax(np.diff(get_rangearray(lookwell)))
    return getLfileWIndex(lookwell,[validLFindx]),look_missed_logs[validLFindx]


 
def removeCorruptlas(awell):
    rewell={}
    for l in awell:
        try:
            if (np.diff(awell[l]['depthrange'])!=0)&(len(awell[l]['categories'])!=0)&(~np.isnan(awell[l]['depthrange'][0])):
                rewell[l]=awell[l]
        except:
            pass
    return rewell
def get_closeValuesIndx(value,val_array,rangelength):
    indexes=[]
    for i,v in enumerate(val_array):
        if (v<=value+rangelength)&(v>=value-rangelength):
            indexes.append(i)
    return indexes
def getIndxGroups(valuearray,rangelength=200):
    temparray=valuearray
    indxarray=np.arange(0,len(valuearray))
#     print(temparray,indxarray)
    indxgroups=[]
    v=temparray[0]+0.00001
    k=0
    while v:
        k+=1
#         print(v,temparray,rangelength)
        vindxes=get_closeValuesIndx(v,temparray,rangelength)
#         print('********************** \n',vindxes)
        v= np.mean(temparray[vindxes])
        vindxes=get_closeValuesIndx(v,temparray,rangelength)
#         print(vindxes)
        indxgroups.append(indxarray[vindxes])
#         print(temparray[vindxes])
    #     del temparray[vindxes]
        temparray=np.delete(temparray, vindxes)

        indxarray=np.delete(indxarray, vindxes)
#         print('temp array: ',temparray)
        if(k==100): break
        if len(temparray)>=1:
            v=temparray[0]
        else:
            break
    return indxgroups   
def suitify(awell):
    global_loglist=getLoglist(awell)
    sorted_well,minmax,dranges=sort_ranges(awell)
#     print_logs(awell)
    pseudo_suitindexes=getIndxGroups(dranges[:,0])
#     print('dranges : ',dranges[:,0])

#     for indgroup in pseudo_suitindexes:
#         print_logs(getLfileWIndex(sorted_well,indgroup))
#         print('********************************************************')
#     # for l in awell:
    suits={}
    for i,indgroup in enumerate(pseudo_suitindexes):
        partwell=getLfileWIndex(sorted_well,indgroup)
        list_availability=[]
        list_missed_logs=[]
        suits[i]={}
        for l in partwell:
            availability,missed_logs=global_logavailability(global_loglist,partwell[l])
            list_availability.append(availability)
            list_missed_logs.append(missed_logs)
        avalawell,miss_log_list=getValidloginRun(partwell,np.array(list_availability),np.array(list_missed_logs))
        miss_log_avail=[]
        if len(miss_log_list)>0:
            for l in partwell:        
                availability,missed_logs=global_logavailability(miss_log_list,partwell[l])        
                miss_log_avail.append(availability)
        miss_log_avail=np.array(miss_log_avail)
        miss_indx=np.argsort(miss_log_avail)
        misavalawell=[]
    #     print(list(avalawell.keys())[0])
        key=list(avalawell.keys())[0]
        suits[i][key]=avalawell[key]
        if miss_log_avail[miss_indx[-1:]]>0:
            misavalawell=getLfileWIndex(partwell,miss_indx[-1:])
            key=list(misavalawell.keys())[0]
            suits[i][key]=misavalawell[key]
    #     print(avalawell)      
    #     print(np.array(miss_log_avail)[miss_indx])
    #     print(misavalawell)
    #     print('****************************************************************')
    return suits   
#         print(awell[l]['depthrange'],', '.join(awell[l]['categories']))

# for indgroup in pseudo_suitindexes:
#     print_logs(getLfileWIndex(sorted_well,indgroup))
wellsuits={}
for i,well in enumerate(well_las_attr_dict):
#     if i==2:
        awell=well_las_attr_dict[well]
#         print_logs(awell)
        print(well)
        awell=removeCorruptlas(awell)
        awell=removeSubsets(awell)
#         print_logs(awell)
        suits=suitify(awell)
        wellsuits[well]=suits
        printSuits(suits)
np.save('wellsuits.npy',[wellsuits])
# suits
# Out:
# W1
#     0
#       W1_SUITE1_COMPOSITE.las : (551.6-1574.0) - CAL, DTC, DTS, GR, SGR, RHOB, NPHI, PE, LLD, LLS, MSFL, SP
#     1
#       W1_SUITE2_COMPOSITE.las : (1477.7-3219.3) - CAL, DTC, DTS, GR, SGR, RHOB, NPHI, PE, LLD, LLS, MSFL, SP
#     2
#       W1_8in_VISION-APWD_RM_MD_ASCII.las : (3189.7-3496.2) - NPHI, LLD
#     3
#       W1_SUITE4_COMPOSITE.las : (3470.0-3672.5) - CAL, GR, SGR, RHOB, NPHI, PE, LLD, SP
# W2
#     0
#       W2_8in_Pilot_VISION_Resistivity_MD_LAS.LAS : (119.8-504.0) - LLD
#     1
#       W2_VISION_RESISTIVITY-APWD_17in_RM_500-1445m.las : (499.9-1445.2) - LLD
#     2
#       W2_12in_DLIS_1430-3100m.las : (1430.0-3100.0) - RHOB, NPHI, LLD
# W3
#     0
#       Dibrugarh1_DLL_150-1852.las : (150.1-1852.2) - CAL, GR, LLD, LLS, MSFL, SP
#       Dibrugarh1_SDL_150-1853.las : (150.3-1853.0) - CAL, GR, RHOB, NPHI, PE
#     1
#       Dibrugarh1_DLL_1772-3310.las : (1772.5-3310.5) - CAL, GR, LLD, LLS, MSFL, SP
#       Dibrugarh1_SDL_1832-3308.las : (1832.9-3308.9) - CAL, GR, RHOB, NPHI, PE
#     2
#       Dibrugarh1_DLL_3293-4300.las : (3293.1-4300.9) - CAL, GR, LLD, LLS, MSFL, SP
#       Dibrugarh1_SDL_3254-4358.las : (3254.5-4358.8) - CAL, GR, RHOB, NPHI, PE
#     3
#       Dibrugarh1_DLL_3961-4367.las : (3961.6-4367.0) - CAL, GR, LLD, LLS, MSFL, SP
#     4
#       Dibrugarh1_DLL_4267-4428.las : (4267.8-4428.9) - CAL, GR, LLD, LLS, MSFL, SP
#       Dibrugarh1_SDL_4285-4428.las : (4285.8-4428.3) - CAL, GR, RHOB, NPHI, PE
# D:\adiarun\Anaconda3\lib\site-packages\ipykernel_launcher.py:134: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.

# %%
# well_las_attr_dict

# %%
global_loglist=getLoglist(awell)
sorted_well,minmax,dranges=sort_ranges(awell)
pseudo_suitindexes=getIndxGroups(dranges[:,0])
print(dranges[:,0],pseudo_suitindexes)
# for i,indgroup in enumerate(pseudo_suitindexes):
#         partwell=getLfileWIndex(sorted_well,indgroup)
# Out:
# 119.78641 [ 119.7864  499.872  1429.9692] 200
# 499.872 [ 499.872  1429.9692] 200
# 1429.9692 [1429.9692] 200
# [ 119.7864  499.872  1429.9692] [array([0]), array([1]), array([2])]

# %%
# wellsuits[list(wellsuits.keys())[2]]
import os
os.path.isfile(wellsuits['BARBAM-1'][0]['Barbam-1_CDL1.las']['path']) 
# for i,well in enumerate(well_las_attr_dict):
#     if i==3:
#         print(i,well)
#         for lf in well_las_attr_dict[well]:
#             # print(well_las_attr_dict[well][lf]['depthrange'])
#                 # well_las_attr_dict[well][lf]={}
#             print('      {:>25} : {:4.1f}-{:4.1f} , {:>15}'.format(lf,min(well_las_attr_dict[well][lf]['depthrange']),max(well_las_attr_dict[well][lf]['depthrange']),
#             ', '.join(well_las_attr_dict[well][lf]['categories'])))
# Out:
# True

# %%
# def dist(a,b,ax=0):
#     return np.linalg.norm(a-b,axis=ax)
# ngroups=4
# # v=0
# # get_closeValuesIndx(v,dranges[:,0],100)
# # from copy import deepcopy
# # Loop will run till the error becomes zero
# X=np.array([dranges[:,0]]*ngroups).T
# C=np.random.choice(dranges[:,0], ngroups)
# C_old=np.zeros(ngroups)
# Cs=C.copy()
# clusters=np.zeros(len(X))
# ithrun=0
# error=dist(C,C_old,None)
# # for j in range(0,1):
# while error > 0.1:
#     ithrun +=1
#     # Assigning each value to its closest cluster
#     print('{}th run'.format(ithrun))
#     for i in range(len(X)):
#         distances = dist(X[i], C)
#         print(distances)
#         print('distances')
#         cluster = np.argmin(distances)
#         clusters[i] = cluster
#     # Storing the old centroid values
#     C_old = C.copy()
#     print(clusters)
#     # Finding the new centroids by taking the average value
#     for i in range(ngroups):
#         points = [X[j] for j in range(len(X)) if clusters[j] == i]
#         C[i] = np.mean(points, axis=0)
#     error = dist(C, C_old, None)
# #     Cs=np.append(Cs,C, axis=0)
#     Cs=np.concatenate((Cs,C), axis=0)
